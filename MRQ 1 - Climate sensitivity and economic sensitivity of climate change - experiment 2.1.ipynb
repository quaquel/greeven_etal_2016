# %% [markdown]
# # Single uncertainty sensitivity analysis - Climate Sensitivity and Economic Sensitivity of Climate Change Uncertainty
# * EMA Society's response to climate change
# * Name: Sebastiaan Greeven
# * Date: 12-5-2015
# #### Introduction
# This notebook contains the single uncertainty sensitivity analysis of the climate sensitivity and economic sensitivity of climate change uncertainty.
#
# 1. Initialisation of the analysis
# 2. GMM analysis of total agreement effect mean for high climate sensitivity
# 3. Visualisation of the sensitivity analysis
# 4. PRIM analysis

# %% [markdown]
# #1. Initialisation of the analysis

# %%
import analysis
import sys
sys.path.append(r'C:\Users\Sebas\Documents\GitHub\EMAworkbench\src')

# %%
% matplotlib inline

import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('whitegrid')
sns.set_palette("deep")

# fig = plt.figure()
# ax = fig.add_subplot(111)
# plt.show()

# %%
import numpy as np

from analysis.plotting import lines, envelopes
from analysis.plotting_util import VIOLIN, KDE
from expWorkbench import load_results
from expWorkbench import ema_logging

import mpld3

# %%
import matplotlib.pyplot as plt

from analysis.pairs_plotting import pairs_lines, pairs_scatter, pairs_density
from expWorkbench.util import load_results

# ema_logging.log_to_stderr(level=ema_logging.DEFAULT_LEVEL)

# %%
from analysis import prim
from analysis.prim import Prim
from expWorkbench import ema_logging

# %%
ema_logging.log_to_stderr(ema_logging.INFO)

results = load_results(r'./data/climate sensitivity 1000 exp 100 rep.tar.gz')
# Out:
# [INFO/MainProcess] results loaded succesfully from ./data/climate sensitivity 1000 exp 100 rep.tar.gz

# %% [markdown]
# #2. Visualisation of the sensitivity analysis

# %%
experiments, outcomes = results

models = set(experiments['model'])

grouped_results = {}
for model in models:
    logical = experiments['model']==model
    
    temp_experiments = experiments[logical]
    temp_outcomes = {key:value[logical] for key, value in outcomes.items()}
    grouped_results[model] = temp_experiments, temp_outcomes

oois = outcomes.keys()
    
for ooi in oois:
    models = list(models)
    ooi_dif = grouped_results[models[0]][1][ooi] - grouped_results[models[1]][1][ooi]
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.hist(ooi_dif[:,-1], bins=20)
    ax.set_ylabel(ooi)
    ax.set_xlabel('Difference')
    plt.show()
    envelopes(results, group_by='model', outcomes_to_show=ooi, fill=True, density='kde')
# Out:
# C:\Users\Sebas\Documents\GitHub\EMAworkbench\src\analysis\plotting_util.py:445: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if time==None:

# %% [markdown]
# #3. GMM analysis of total agreement effect mean for high climate sensitivity

# %%
experiments, outcomes = load_results(r'./data/ClimateSensitivity 1000 exp 100 rep.tar.gz')

data = outcomes['TotalAgreementEffect_mean'] [:,-1]
logical = experiments['model']=='HighClimateSensitivity'
data = data[logical]

fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(data, bins=20)
plt.show()
# Out:
# [INFO/MainProcess] results loaded succesfully from ./data/ClimateSensitivity 1000 exp 100 rep.tar.gz

# %%
from sklearn import mixture
aic = []
bic = []
max_components = 10
x = [x for x in range (1, max_components)]

for nc in x:
    g = mixture.GMM(n_components=int(nc), n_iter=300)
    g.fit(data)
    if g.converged_:
        aic.append(g.aic(data))
        bic.append(g.aic(data))
    else:
        aic.append(None)
        bic.append(None)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(x, aic, label="aic")
ax.plot(x, aic, label="bic")
ax.set_xlabel('nr. of components')
ax.grid()
plt.show()

# %%
g = mixture.GMM(n_components=2, n_iter=300)
g.fit(data)
pred = g.predict(data)


logical = pred==0
subset_0 = data[logical]
logical = pred==1
subset_1 = data[logical]

fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist([subset_0, subset_1], bins=20)
plt.show()

# %%
logical = experiments['model']=='HighClimateSensitivity'

temp_experiments = experiments[logical]
temp_outcomes = {'classes':pred}

from analysis.prim import Prim

prim_obj = Prim((temp_experiments, temp_outcomes), classify='classes', threshold=0.7)
box1 = prim_obj.find_box()
# Out:
# [INFO/MainProcess] 1000 points remaining, containing 485 cases of interest
# [INFO/MainProcess] mean: 1.0, mass: 0.266, coverage: 0.548453608247, density: 1.0 restricted_dimensions: 5.0

# %%
box1.show_tradeoff()
mpld3.display()
# Out:
# <style>
#
#             table
#             {
#               border-collapse: collapse;
#             }
#             th
#             {
#               background-color:  rgba(255,255,255,0.6);;;
#             }
#             td
#             {
#               background-color: rgba(255,255,255,0.6);;
#             }
#             table, th, td
#             {
#               font-family:Tahoma, Tahoma, sans-serif;
#               font-size: 16px;
#               border: 1px solid black;
#               text-align: right;
#             }
#
# </style>
#
# <div id="fig_el15644000212089910426753"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#        mpld3.draw_figure("fig_el15644000212089910426753", {"axes": [{"xlim": [0.0, 1.2], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "coverage", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.068426197458455532], "rotation": -0.0, "id": "el1564387334328"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "density", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.070459509408602128, 0.5], "rotation": -90.0, "id": "el1564454380792"}], "zoomable": true, "images": [], "xdomain": [0.0, 1.2], "ylim": [0.0, 1.2], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [], "markers": [], "id": "el1564438773968", "ydomain": [0.0, 1.2], "collections": [{"paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgecolors": ["#000000"], "edgewidths": [0.3], "offsets": "data01", "yindex": 1, "id": "el1564387357440", "pathtransforms": [[4.969039949999533, 0.0, 0.0, 4.969039949999533, 0.0, 0.0]], "pathcoordinates": "display", "offsetcoordinates": "data", "zorder": 1, "xindex": 0, "alphas": [null], "facecolors": ["#081D58", "#234DA0", "#2498C0", "#72C8BC", "#D6EFB2", "#D6EFB2", "#D6EFB2", "#FFFFD9"]}], "xscale": "linear", "bbox": [0.125, 0.125, 0.62, 0.77500000000000002]}, {"xlim": [0.0, 1.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "nr. of restricted dimensions", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [2.1055107526881685, 0.5], "rotation": -90.0, "id": "el1564457291480"}], "zoomable": false, "images": [], "xdomain": [0.0, 1.0], "ylim": [0.0, 1.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "fontsize": null, "position": "bottom", "nticks": 0, "tickvalues": []}, {"scale": "linear", "tickformat": null, "grid": {"gridOn": false}, "fontsize": 10.0, "position": "right", "nticks": 6, "tickvalues": [0.083333333333333329, 0.25, 0.41666666666666663, 0.58333333333333326, 0.75, 0.91666666666666663]}], "lines": [], "markers": [], "id": "el1564457553904", "ydomain": [0.0, 1.0], "collections": [{"paths": [[[[0.0, 0.0], [1.0, 0.0], [1.0, 0.16666666666666666], [0.0, 0.16666666666666666], [0.0, 0.0]], ["M", "L", "L", "L", "L"]], [[[0.0, 0.16666666666666666], [1.0, 0.16666666666666666], [1.0, 0.3333333333333333], [0.0, 0.3333333333333333], [0.0, 0.16666666666666666]], ["M", "L", "L", "L", "L"]], [[[0.0, 0.3333333333333333], [1.0, 0.3333333333333333], [1.0, 0.5], [0.0, 0.5], [0.0, 0.3333333333333333]], ["M", "L", "L", "L", "L"]], [[[0.0, 0.5], [1.0, 0.5], [1.0, 0.6666666666666666], [0.0, 0.6666666666666666], [0.0 ...

# %%
box1.inspect(1, style='graph')
plt.show()
